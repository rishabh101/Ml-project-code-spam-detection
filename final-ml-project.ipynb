# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

df=pd.read_csv("../input/projectdata/our_contest_train_2.csv")

# %%
df

# %%
y=df['Target']

# %%
df

# %%
df.isnull().sum()

# %%
df=df.dropna(subset=['MainText','PrimarySubject'])

# %%
df.isnull().sum()

# %%
df

# %%
from nltk.corpus import stopwords

# %%
df['Heading']

# %%
df=df.fillna("")

# %%
df.isnull().sum()

# %%
import nltk.data

# %%
df['Heading']

# %%
df_heading=df["Heading"]

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
from nltk.corpus import stopwords

# %% [markdown]
# **BAG OF WORDS FOR MULTINOMIAL BAYES**

# %%
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
corpus = []
df['Heading'] = df['Heading'].replace('[^a-zA-Z]', '');
df['Heading'] = df['Heading'].str.lower()#converting into lower case
df['Heading'] = df['Heading'].str.split()

# %%
df['Heading']

# %%
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

# %%
stop_words = set(stopwords.words('english'))
df['Heading'] = df['Heading'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
df.info()

# %%
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

# %%
def lemmatization(token_text):
    text=[lemmatizer.lemmatize(word) for word in token_text]
    return text

# %%
df['Heading']=df['Heading'].apply(lambda x : lemmatization(x))
df['Heading']=df['Heading'].apply(lambda x: ' '.join(x))

# %%
df['Heading']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)#we sre selecting only 2500 most important features
X = cv.fit_transform(df['Heading'])

# %%
from gensim.models import word2vec

# %% [markdown]
# **End**

# %%
y=df["Target"]

# %%
y=y

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
y.shape[0]

# %%
from sklearn.naive_bayes import MultinomialNB
spam_detect_model = MultinomialNB().fit(X_train, y_train)

# %%
y_pred=spam_detect_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_m = confusion_matrix(y_test,y_pred)
confusion_m

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test, y_pred, average=None)

# %% [markdown]
# **Test**

# %%
import pandas as pd

# %%
df1=pd.read_csv("../input/testdata1/our_contest_test.csv")

# %%
df1

# %%
df1.isnull().sum()

# %%
df1=df1.fillna("")

# %%
import nltk.data

# %%
df1.isnull().sum()

# %%
import nltk.data
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
from nltk.corpus import stopwords

# %%
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
df1['Heading'] = df1['Heading'].replace('[^a-zA-Z]', '');
df1['Heading'] = df1['Heading'].str.lower()#converting into lower case
df1['Heading'] = df1['Heading'].str.split()

# %%
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

# %%
stop_words = set(stopwords.words('english'))
df1['Heading'] = df1['Heading'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
def lemmatization(token_text):
    text=[lemmatizer.lemmatize(word) for word in token_text]
    return text

# %%
df1['Heading']=df1['Heading'].apply(lambda x : lemmatization(x))
df1['Heading']=df1['Heading'].apply(lambda x: ' '.join(x))

# %%
df1["Heading"]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)#we sre selecting only 2500 most important features
X1 = cv.fit_transform(df1['Heading'])

# %%
X1

# %%
df1.info()

# %%
df1

# %%
from sklearn.naive_bayes import MultinomialNB
spam_detect_model = MultinomialNB().fit(X, y)

# %%
y_pred=spam_detect_model.predict(X1)

# %% [markdown]
# **Submission**

# %%
df1

# %%
df1['Target']=y_pred

# %%
data1=df1['Qid']

# %%
df2=pd.DataFrame(data1,columns=['Qid'])

# %%
df2

# %%
df2['Target']=y_pred

# %%
df2

# %%
to_submit=df2

# %%
to_submit

# %%
to_submit.to_csv("/kaggle/working/bayes1.csv",index=False)

# %% [markdown]
# **WORD2VEC**

# %% [markdown]
# from gensim.models import Word2Vec

# %% [markdown]
# **TFIDF FOR LOGISTIC ******

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(max_features=2500)
X1=vectorizer.fit_transform(df["Heading"])

# %%
vectorizer=TfidfVectorizer(max_features=2500)

# %%
X=vectorizer.fit_transform(df["Heading"])

# %%
X

# %%
y=df["Target"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# **MULTINOMIAL  LOGISTIC ON BAG OF WORDS **

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(multi_class='multinomial', solver='newton-cg')

# %%
model.fit(X_train, y_train)

# %%
y_pred=model.predict(X_test)

# %%
y_pred

# %%
from sklearn.metrics import confusion_matrix
confusion_m = confusion_matrix(y_test,y_pred)
confusion_m

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test, y_pred, average=None)

# %% [markdown]
# **TESTING FOR LOGISTIC REGRESSION**

# %%
df1=pd.read_csv("../input/testdata1/our_contest_test.csv")

# %%
df1

# %%
df1.isnull().sum()

# %%
df1=df1.fillna("")

# %%
df1.isnull().sum()

# %%
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
X1Test=X1

# %%
model.fit(X,y)

# %%
ypred1=model.predict(X1Test)

# %%
ypred1

# %% [markdown]
# **Submission**

# %%
df1['Target']=ypred1
data1=df1['Qid']

# %%
df2=pd.DataFrame(data1,columns=['Qid'])
df2

# %%
to_submit=df2
to_submit
to_submit.to_csv("/kaggle/working/logistic1.csv",index=False)

# %% [markdown]
# **Ending till the second Evaluation**

# %%
s

# %%
s1

# %% [markdown]
# **ONE VS REST LOGISTIC REGRESSION ON BAG OF WORDS**

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(multi_class='ovr',solver='liblinear',class_weight='balanced')
model.fit(X_train, y_train)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_m = confusion_matrix(y_test,y_pred)
confusion_m

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test, y_pred, average=None)

# %% [markdown]
# **Testing for Logistic Regression**

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)#we sre selecting only 2500 most important features
Xcounttest = cv.fit_transform(df1['Heading'])

# %%
model.fit(X,y)

# %%
ypred1c=model.predict(Xcounttest)

# %% [markdown]
# **Submission**

# %%
data1=df1['Qid']

# %%
df2=pd.DataFrame(data1,columns=['Qid'])
df2
df2['Target']=ypred1c

# %%
df2

# %%
to_submit=df2
to_submit
to_submit.to_csv("/kaggle/working/logistic4.csv",index=False)
